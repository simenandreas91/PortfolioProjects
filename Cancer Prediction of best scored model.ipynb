# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn import svm, datasets
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
# Loading the dataset.
cancer = datasets.load_breast_cancer()
dir(cancer)
# Out:
# ['DESCR',
#  'data',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
# Making a dataframe out of it.
df = pd.DataFrame(cancer.data, columns=cancer.feature_names)
df['target'] = cancer.target
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  radius error  texture error  perimeter error  \
# ...

# %%
df.target.value_counts()
# Out:
# 1    357
# 0    212
# Name: target, dtype: int64

# %%
# Define x and y.
x = df.drop(['target'], axis='columns')
y = df['target']

# Spliting the data for train and test.
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
# Making three models ready to be looped through with some different parameters.
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto'),
        'params' : {
            'C': [1,10,20],
            'kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'C': [1,5,10]
        }
    }
}

# %%
# Creating a empty list to store the scores.
scores = []

# Looping through the models and the params to find the best fit for the dataset.
for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })

# Creating a dataframe to display the results
df3 = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df3
# Out:
#                  model  best_score                    best_params
# 0                  svm    0.956044  {'C': 10, 'kernel': 'linear'}
# 1        random_forest    0.956044           {'n_estimators': 10}
# 2  logistic_regression    0.949451                       {'C': 5}

# %%
# Run the data through the model with the best fit parameters.
from sklearn.svm import SVC
model = SVC(C=10, kernel = 'linear')
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.9298245614035088

# %%
# Display the dataframe once more.
pd.set_option("display.max_columns", None)
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  radius error  texture error  perimeter error  \
# ...

# %%
# Predict a target of 0 (no cancer), og 1 (cancer) based on values of the features.
model.predict([[17.99,10.38,122.80,1001.0,0.11840,0.27760,0.3001,0.14710,0.2419,0.07871,1.0950,0.9053,8.589,153.40,0.006399,0.04904,0.05373,0.01587,0.03003,0.006193,25.38,17.33,184.60,2019.0,0.1622,0.6656,0.7119,0.2654,0.4601,0.11890]])
# Out:
# array([0])

# %% [markdown]
# ### The values of the prediction is the same as the one in index_0, which is target = 0.
# The prediction is 0 which is aligned with the first row!
